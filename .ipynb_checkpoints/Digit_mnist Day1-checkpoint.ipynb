# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from keras.datasets import mnist
import random
# Out:
# Using TensorFlow backend.

# %%
(xtr,ytr),(xts,yts) = mnist.load_data()

# %%
plt.imshow(xtr[0])
plt.title(ytr[0])
plt.show()

# %%
print('xtr shape',xtr.shape,sep=':')
print('ytr shape',ytr.shape,sep=':')
# Out:
# xtr shape:(60000, 28, 28)
# ytr shape:(60000,)

# %%
n_cols = 5
n_classes = 10

fig,axes = plt.subplots(nrows=n_classes,ncols=n_cols,figsize=(5,10))
fig.tight_layout()

for i in range(n_cols):
    for j in range(n_classes):
        
        images = xtr[ytr==j]
        selected_image = images[random.randint(0,(len(images)-1)),:,:]
        axes[j][i].imshow(selected_image,cmap='gray')
        axes[j][i].axis('off')
        if i==2:
            axes[j][i].set_title(str(j))

# %%
sns.countplot(ytr)
plt.show()

# %% [markdown]
# # Pre-processing

# %%
n_pixels = xtr.shape[1]*xtr.shape[2]

xtr = xtr.reshape(xtr.shape[0],n_pixels)

xtr = xtr/255

# %%
xts = xts.reshape(xts.shape[0],n_pixels)
xts = xts/255

# %% [markdown]
# # OneHotEncoding ytr array

# %%
from keras.utils.np_utils import to_categorical
ytr = to_categorical(ytr,10)   #10 represents number of classes/categories
yts = to_categorical(yts,10)

# %% [markdown]
# # Creating Nural Net Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
def create_model():
    model = Sequential()
    model.add(Dense(64,input_dim=n_pixels,activation='relu'))
    model.add(Dense(10,activation='softmax'))
    model.compile(Adam(lr=0.01),loss='categorical_crossentropy',metrics=['accuracy'])
    return model

model = create_model()
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                50240
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
h = model.fit(xtr,ytr,epochs=10,  verbose=1, validation_data=(xts,yts),batch_size=20)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 12s 205us/step - loss: 0.2761 - accuracy: 0.9204 - val_loss: 0.1974 - val_accuracy: 0.9458
# Epoch 2/10
# 60000/60000 [==============================] - 8s 136us/step - loss: 0.1965 - accuracy: 0.9458 - val_loss: 0.1843 - val_accuracy: 0.9493
# Epoch 3/10
# 60000/60000 [==============================] - 16s 263us/step - loss: 0.1726 - accuracy: 0.9534 - val_loss: 0.1872 - val_accuracy: 0.9528
# Epoch 4/10
# 60000/60000 [==============================] - 16s 275us/step - loss: 0.1564 - accuracy: 0.9571 - val_loss: 0.1895 - val_accuracy: 0.9548
# Epoch 5/10
# 60000/60000 [==============================] - 16s 261us/step - loss: 0.1582 - accuracy: 0.9595 - val_loss: 0.2240 - val_accuracy: 0.9506
# Epoch 6/10
# 60000/60000 [==============================] - 8s 136us/step - loss: 0.1463 - accuracy: 0.9612 - val_loss: 0.2370 - val_accuracy: 0.9500
# Epoch 7/10
# 60000/60000 [==============================] - 12s 198us/step - loss: 0.1448 - accuracy: 0.9642 - val_loss: 0.2428 - val_accuracy: 0.9507
# Epoch 8/10
# 10760/60000 [====>.........................] - ETA: 6s - loss: 0.1312 - accuracy: 0.9653

# %%
model.save('model.h5')

# %% [markdown]
# # Predicting images

# %%
import cv2

# %%
img = cv2.imread(r"C:\Users\mukes\Desktop\Datasets\digit.png")

# %%
img.shape

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img = cv2.resize(img,(28,28))
plt.imshow(img,cmap='gray')
plt.show()

# %%
img = img.reshape(1,n_pixels)
img = img/255

# %%
model.predict_classes(img)

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = model.predict_classes(xts)
